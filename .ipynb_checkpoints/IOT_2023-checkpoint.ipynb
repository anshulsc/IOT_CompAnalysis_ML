# %%
import pandas as pd
import pyarrow.parquet as pq
from sklearn.metrics import classification_report
import time
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Collection and Preprocessing

# %%
table = pq.read_table('data/iot.parquet')

# Convert the table to a Pandas dataframe
df = table.to_pandas()

# %%
df.value_counts('detailed_label')
# Out:
# detailed_label
# PartOfAHorizontalPortScan        43921134
# Okiru                            13487413
# benign                           11585824
# DDoS                              2943063
# C&C                                 21779
# C&C-HeartBeat                       21331
# Attack                               3396
# C&C-PartOfAHorizontalPortScan         878
# dtype: int64

# %%
df_majority = df[df.labels == 1]
df_minority7 = df[df.detailed_label == 'benign']

df_majority_downsampled = df_majority.sample(n=723857, random_state=42)
df_minority7_downsampled = df_minority7.sample(n=713857, random_state=42)

# Combine the downsampled majority class and all the minority classes
df_downsampled = pd.concat([df_majority_downsampled, df_minority7_downsampled])

# Shuffle the DataFrame
df_d = df_downsampled.sample(frac=1, random_state=42)

# %%
df_d.value_counts('detailed_label')
# Out:
# detailed_label
# benign                           713857
# PartOfAHorizontalPortScan        526299
# Okiru                            161870
# DDoS                              35103
# C&C-HeartBeat                       271
# C&C                                 261
# Attack                               39
# C&C-PartOfAHorizontalPortScan        14
# dtype: int64

# %%
df_d.to_csv("data/df_equalsampled.csv")

# %% [markdown]
# # -----------------------------------------------------------------

# %%
df_d  = pd.read_csv("data/df_equalsampled.csv")

# %%
df_d = df_d.iloc[:,1:]

# %%
df_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1437714 entries, 0 to 1437713
# Data columns (total 18 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   ts              1437714 non-null  float64
#  1   id_orig_h       1437714 non-null  float64
#  2   id_orig_p       1437714 non-null  float64
#  3   id_resp_h       1437714 non-null  float64
#  4   id_resp_p       1437714 non-null  float64
#  5   proto           1437714 non-null  object
#  6   duration        1437714 non-null  float64
#  7   orig_bytes      1437714 non-null  int64
#  8   resp_bytes      1437714 non-null  int64
#  9   conn_state      1437714 non-null  object
#  10  missed_bytes    1437714 non-null  float64
#  11  history         1437273 non-null  object
#  12  orig_pkts       1437714 non-null  float64
#  13  orig_ip_bytes   1437714 non-null  float64
#  14  resp_pkts       1437714 non-null  float64
#  15  resp_ip_bytes   1437714 non-null  float64
#  16  detailed_label  1437714 non-null  object
#  17  labels          1437714 non-null  int64
# dtypes: float64(11), int64(3), object(4)
# memory usage: 197.4+ MB

# %%
def map_label(label):
    if label == 1:
        return "malicious"
    else:
        return "benign"

# example usage
df_d["labels"] = df_d["labels"].apply(map_label)

# %%
df_d["super_label"] = df_d["labels"]  + "_" + df_d["detailed_label"]

# %%
df_s = df_d.drop(columns=["detailed_label","conn_state"])

# %%
df_s
# Out:
#                    ts     id_orig_h  id_orig_p     id_resp_h  id_resp_p proto  \
# 0        1.547084e+09  3.232236e+09    46997.0  1.741274e+09       22.0   tcp
# 1        1.545434e+09  3.232236e+09    40906.0  1.692058e+09       23.0   tcp
# 2        1.547148e+09  3.232236e+09    50708.0  3.569210e+07       23.0   tcp
# 3        1.547145e+09  3.232236e+09    25542.0  3.262870e+09       23.0   tcp
# 4        1.547146e+09  3.232236e+09    50708.0  2.785092e+09       23.0   tcp
# ...               ...           ...        ...           ...        ...   ...
# 1437709  1.547071e+09  3.232236e+09    40765.0  9.886176e+08       22.0   tcp
# 1437710  1.547147e+09  3.232236e+09    52989.0  1.604247e+09       23.0   tcp
# 1437711  1.545448e+09  3.232236e+09    36097.0  3.695995e+09    37215.0   tcp
# 1437712  1.547076e+09  3.232236e+09    44476.0  1.016251e+09       22.0   tcp
# 1437713  1.532105e+09  3.232261e+09     5526.0  2.071908e+09    37215.0   tcp
#
#          duration  orig_bytes  resp_bytes  missed_bytes history  orig_pkts  \
# 0             0.0           0           0           0.0       S        1.0
# 1             0.0           0           0           0.0       S        1.0
# 2             0.0           0           0           0.0       S        1.0
# 3             0.0           0           0           0.0       S        1.0
# 4             0.0           0           0           0.0       S        1.0
# ...           ...         ...         ...           ...     ...        ...
# 1437709       0.0           0           0           0.0       S        1.0
# 1437710       0.0           0           0           0.0       S        1.0
# 1437711       0.0           0           0           0.0       S        1.0
# 1437712       0.0           0           0           0.0       S        1.0
# 1437713       0.0           0           0           0.0       S        1.0
#
#          orig_ip_bytes  resp_pkts  resp_ip_bytes     labels  \
# 0                 40.0        0.0            0.0  malicious
# 1                 60.0        0.0            0.0     benign
# 2                 40.0        0.0            0.0     benign
# 3                 40.0        0.0            0.0     benign
# 4                 40.0        0.0            0.0     benign
# ...                ...        ...            ...        ...
# 1437709           40.0        0.0            0.0  malicious
# 1437710           40.0        0.0            0.0     benign
# 1437711           40.0        0.0            0.0  malicious
# 1437712           40.0        0.0            0.0  malicious
# 1437713           40.0        0.0            0.0  malicious
#
#                                  super_label
# 0        malicious_PartOfAHorizontalPortScan
# 1                              benign_benign
# 2                              benign_benign
# 3                              benign_benign
# 4                              benign_benign
# ...                                      ...
# 1437709  malicious_PartOfAHorizontalPortScan
# 1437710                        benign_benign
# 1437711                      malicious_Okiru
# 1437712  malicious_PartOfAHorizontalPortScan
# 1437713                      malicious_Okiru
#
# [1437714 rows x 17 columns]

# %%
df_d['labels'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot: ylabel='labels'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df_s[["ts","id_orig_h","id_orig_p","id_resp_h"]] = scaler.fit_transform(df_s[["ts","id_orig_h","id_orig_p","id_resp_h"]])

# %%
df_s.value_counts("super_label")
# Out:
# super_label
# benign_benign                              713857
# malicious_PartOfAHorizontalPortScan        526299
# malicious_Okiru                            161870
# malicious_DDoS                              35103
# malicious_C&C-HeartBeat                       271
# malicious_C&C                                 261
# malicious_Attack                               39
# malicious_C&C-PartOfAHorizontalPortScan        14
# dtype: int64

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1437714 entries, 0 to 1437713
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   ts             1437714 non-null  float64
#  1   id_orig_h      1437714 non-null  float64
#  2   id_orig_p      1437714 non-null  float64
#  3   id_resp_h      1437714 non-null  float64
#  4   id_resp_p      1437714 non-null  float64
#  5   proto          1437714 non-null  object
#  6   duration       1437714 non-null  float64
#  7   orig_bytes     1437714 non-null  int64
#  8   resp_bytes     1437714 non-null  int64
#  9   missed_bytes   1437714 non-null  float64
#  10  history        1437273 non-null  object
#  11  orig_pkts      1437714 non-null  float64
#  12  orig_ip_bytes  1437714 non-null  float64
#  13  resp_pkts      1437714 non-null  float64
#  14  resp_ip_bytes  1437714 non-null  float64
#  15  labels         1437714 non-null  object
#  16  super_label    1437714 non-null  object
# dtypes: float64(11), int64(2), object(4)
# memory usage: 186.5+ MB

# %%
df_s[["id_resp_p","duration","orig_bytes","resp_bytes","missed_bytes","orig_pkts","orig_ip_bytes","resp_pkts","resp_ip_bytes"]] = scaler.fit_transform(df_s[["id_resp_p","duration","orig_bytes","resp_bytes","missed_bytes","orig_pkts","orig_ip_bytes","resp_pkts","resp_ip_bytes"]])

# %%
from sklearn.preprocessing import LabelEncoder

# Load the dataset

# Encode the labels column using LabelEncoder
le = LabelEncoder()
df_s['super_label'] = le.fit_transform(df_s['super_label'])
df_s['labels'] = le.fit_transform(df_s['labels'])
df_s['proto'] = le.fit_transform(df_s['proto'])
df_s['history'] = le.fit_transform(df_s['history'])

# %%
df_s
# Out:
#                ts  id_orig_h  id_orig_p  id_resp_h  id_resp_p  proto  \
# 0        0.098744   0.009686   0.499769  -0.293327  -0.531045      1
# 1       -0.257148   0.009686   0.121484  -0.340883  -0.530993      1
# 2        0.112595   0.009686   0.730243  -1.941372  -0.530993      1
# 3        0.111948   0.009686  -0.832705   1.176939  -0.530993      1
# 4        0.112207   0.009686   0.730243   0.715278  -0.530993      1
# ...           ...        ...        ...        ...        ...    ...
# 1437709  0.095939   0.009686   0.112727  -1.020593  -0.531045      1
# 1437710  0.112358   0.009686   0.871905  -0.425731  -0.530993      1
# 1437711 -0.254235   0.009686  -0.177181   1.595452   1.389595      1
# 1437712  0.096931   0.009686   0.343201  -0.993892  -0.531045      1
# 1437713 -3.133086   0.010679  -2.075809   0.026153   1.389595      1
#
#          duration  orig_bytes  resp_bytes  missed_bytes  history  orig_pkts  \
# 0       -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
# 1       -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
# 2       -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
# 3       -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
# 4       -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
# ...           ...         ...         ...           ...      ...        ...
# 1437709 -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
# 1437710 -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
# 1437711 -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
# 1437712 -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
# 1437713 -0.048685   -0.001284   -0.006228     -0.001123        8  -0.000917
#
#          orig_ip_bytes  resp_pkts  resp_ip_bytes  labels  super_label
# 0            -0.001018  -0.005068      -0.006246       1            7
# 1            -0.000846  -0.005068      -0.006246       0            0
# 2            -0.001018  -0.005068      -0.006246       0            0
# 3            -0.001018  -0.005068      -0.006246       0            0
# 4            -0.001018  -0.005068      -0.006246       0            0
# ...                ...        ...            ...     ...          ...
# 1437709      -0.001018  -0.005068      -0.006246       1            7
# 1437710      -0.001018  -0.005068      -0.006246       0            0
# 1437711      -0.001018  -0.005068      -0.006246       1            6
# 1437712      -0.001018  -0.005068      -0.006246       1            7
# 1437713      -0.001018  -0.005068      -0.006246       1            6
#
# [1437714 rows x 17 columns]

# %%
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1437714 entries, 0 to 1437713
# Data columns (total 17 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   ts             1437714 non-null  float64
#  1   id_orig_h      1437714 non-null  float64
#  2   id_orig_p      1437714 non-null  float64
#  3   id_resp_h      1437714 non-null  float64
#  4   id_resp_p      1437714 non-null  float64
#  5   proto          1437714 non-null  int64
#  6   duration       1437714 non-null  float64
#  7   orig_bytes     1437714 non-null  float64
#  8   resp_bytes     1437714 non-null  float64
#  9   missed_bytes   1437714 non-null  float64
#  10  history        1437714 non-null  int64
#  11  orig_pkts      1437714 non-null  float64
#  12  orig_ip_bytes  1437714 non-null  float64
#  13  resp_pkts      1437714 non-null  float64
#  14  resp_ip_bytes  1437714 non-null  float64
#  15  labels         1437714 non-null  int64
#  16  super_label    1437714 non-null  int64
# dtypes: float64(13), int64(4)
# memory usage: 186.5 MB

# %%
df_s['super_label'].value_counts()
# Out:
# 0    713857
# 7    526299
# 6    161870
# 5     35103
# 3       271
# 2       261
# 1        39
# 4        14
# Name: super_label, dtype: int64

# %%
X = df_s.iloc[:,1:14]
y = df_s.iloc[:,15]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
kernal_evals = dict()
def evaluate_classification(model, name, X_train, X_test, y_train, y_test):
    train_accuracy = metrics.accuracy_score(y_train, model.predict(X_train))
    test_accuracy = metrics.accuracy_score(y_test, model.predict(X_test))
    
    train_precision = metrics.precision_score(y_train, model.predict(X_train),average='macro',zero_division=1)
    test_precision = metrics.precision_score(y_test, model.predict(X_test),average='macro',zero_division=1)
    
    train_recall = metrics.recall_score(y_train, model.predict(X_train),average='macro',zero_division=1)
    test_recall = metrics.recall_score(y_test, model.predict(X_test),average='macro',zero_division=1)
    
    kernal_evals[str(name)] = [train_accuracy, test_accuracy, train_precision, test_precision, train_recall, test_recall]
    print("Training Accuracy " + str(name) + " {} || Test Accuracy ".format(train_accuracy*100) + str(name) + " {}".format(test_accuracy*100))
    print("Training Precesion " + str(name) + "{} || Test Precesion ".format(train_precision*100) + str(name) + " {}".format(test_precision*100))
    print("Training Recall " + str(name) + "  {}  || Test Recall ".format(train_recall*100) + str(name) + " {}".format(test_recall*100))
    
    actual = y_test
    predicted = model.predict(X_test)
    confusion_matrix = metrics.confusion_matrix(actual, predicted)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)

    fig, ax = plt.subplots(figsize=(5,5))
    ax.grid(False)
    cm_display.plot(ax=ax)

# %%
from sklearn.metrics import roc_curve, auc
def plot_roc(model,X_test):
    y_pred_prob_rf = model.predict_proba(X_test)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(len(model.classes_)):
        fpr[i], tpr[i], _ = roc_curve(y_test, y_pred_prob_rf[:, i], pos_label=model.classes_[i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot ROC curve for each class
    plt.figure()
    colors = ['blue', 'red', 'green', 'orange', 'purple'] # You can add more colors for more classes
    for i, color in zip(range(len(model.classes_)), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2, label='ROC curve for class {} (area = {:.2f})'.format(i, roc_auc[i]))
    plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
start = time.time()
model = RandomForestClassifier()
model.fit(X_train, y_train)
end = time.time()
print("Time taken by Random Forest Classifier:", end - start)
# Out:
# Time taken by Random Forest Classifier: 51.27195405960083

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    143058
#            1       1.00      1.00      1.00    144485
#
#     accuracy                           1.00    287543
#    macro avg       1.00      1.00      1.00    287543
# weighted avg       1.00      1.00      1.00    287543

# %%
evaluate_classification(model, "Random Forest", X_train, X_test, y_train, y_test)
# Out:
# Training Accuracy Random Forest 100.0 || Test Accuracy Random Forest 99.99895667778385
# Training Precesion Random Forest100.0 || Test Precesion Random Forest 99.99895838038795
# Training Recall Random Forest  100.0  || Test Recall Random Forest 99.99895492613406

# %%
plot_roc(model,X_test)

# %% [markdown]
# ##  Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
start = time.time()
dt = DecisionTreeClassifier(max_depth=3).fit(X_train, y_train)
tdt = DecisionTreeClassifier().fit(X_train, y_train)
end = time.time()
print(f"Time taken by Decision Tree: {end - start}s" )
# Out:
# Time taken by Decision Tree: 2.6751859188079834s

# %%
y_pred = tdt.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    143058
#            1       1.00      1.00      1.00    144485
#
#     accuracy                           1.00    287543
#    macro avg       1.00      1.00      1.00    287543
# weighted avg       1.00      1.00      1.00    287543

# %%
evaluate_classification(tdt, "Decision Tree", X_train, X_test, y_train, y_test)
# Out:
# Training Accuracy Decision Tree 100.0 || Test Accuracy Decision Tree 99.9986089037118
# Training Precesion Decision Tree100.0 || Test Precesion Decision Tree 99.99861233084093
# Training Recall Decision Tree  100.0  || Test Recall Decision Tree 99.99860541754315

# %%
plot_roc(tdt,X_test)

# %% [markdown]
# #  Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
start = time.time()
nb = GaussianNB()
nb.fit(X_train, y_train)
end = time.time()
print(f"Time taken by Naive Bayes: {end - start}s" )
# Out:
# Time taken by Naive Bayes: 0.20278000831604004s

# %%
y_pred = nb.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79    143058
#            1       1.00      0.47      0.64    144485
#
#     accuracy                           0.73    287543
#    macro avg       0.82      0.73      0.71    287543
# weighted avg       0.83      0.73      0.71    287543

# %%
evaluate_classification(nb, "Naive Bayes", X_train, X_test, y_train, y_test)
# Out:
# Training Accuracy Naive Bayes 73.2799731518183 || Test Accuracy Naive Bayes 73.28990794420312
# Training Precesion Naive Bayes82.42842379800646 || Test Precesion Naive Bayes 82.46427679225383
# Training Recall Naive Bayes  73.47709559376253  || Test Recall Naive Bayes 73.42144949392005

# %%
plot_roc(nb,X_test)

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier
start = time.time()
clf = MLPClassifier(hidden_layer_sizes=(100,50), max_iter=1000, random_state=42)
clf.fit(X_train, y_train)
end = time.time()
print(f"Time taken by MLP: {end - start}s" )
# Out:
# Time taken by MLP: 2114.5382590293884s

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97    143058
#            1       0.95      0.99      0.97    144485
#
#     accuracy                           0.97    287543
#    macro avg       0.97      0.97      0.97    287543
# weighted avg       0.97      0.97      0.97    287543

# %%
evaluate_classification(clf, "MLP", X_train, X_test, y_train, y_test)
# Out:
# Training Accuracy MLP 97.07008783911262 || Test Accuracy MLP 97.08321885770128
# Training Precesion MLP97.14989416683805 || Test Precesion MLP 97.15556941497248
# Training Recall MLP  97.05582595792613  || Test Recall MLP 97.07398393256528

# %%
plot_roc(clf,X_test)

# %% [markdown]
# ## KNN MODEL

# %%
from sklearn.neighbors import KNeighborsClassifier
start = time.time()
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
end = time.time()
print(f"Time taken by KNN: {end - start}s" )
# Out:
# Time taken by KNN: 0.7121801376342773s

# %%
y_pred = knn.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.91    143058
#            1       0.90      0.92      0.91    144485
#
#     accuracy                           0.91    287543
#    macro avg       0.91      0.91      0.91    287543
# weighted avg       0.91      0.91      0.91    287543

# %%
evaluate_classification(knn, "KNN", X_train, X_test, y_train, y_test)
# Out:
# Training Accuracy KNN 93.47227499215333 || Test Accuracy KNN 90.85423745318091
# Training Precesion KNN93.51613046112412 || Test Precesion KNN 90.88874309944688
# Training Recall KNN  93.46115539078448  || Test Recall KNN 90.84724300963987

# %%
evaluate_classification(knn, "KNN", X_train, X_test, y_train, y_test)

# %%
y_pred_knn = knn.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_knn)

# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve')
plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
